# %%
import pandas as pd
import numpy as np


social_network_file_path = 'http://iali.in/datasets/Social_Network_Ads.csv'
social_network_data = pd.read_csv(social_network_file_path)
social_network_data.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
social_network_data_new = social_network_data.dropna(axis=0)
social_network_data_new.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
x = social_network_data_new.Purchased
x
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
y = social_network_data_new.iloc[:,[2,3]].values
y
# Out:
# array([[    19,  19000],
#        [    35,  20000],
#        [    26,  43000],
#        [    27,  57000],
#        [    19,  76000],
#        [    27,  58000],
#        [    27,  84000],
#        [    32, 150000],
#        [    25,  33000],
#        [    35,  65000],
#        [    26,  80000],
#        [    26,  52000],
#        [    20,  86000],
#        [    32,  18000],
#        [    18,  82000],
#        [    29,  80000],
#        [    47,  25000],
#        [    45,  26000],
#        [    46,  28000],
#        [    48,  29000],
#        [    45,  22000],
#        [    47,  49000],
#        [    48,  41000],
#        [    45,  22000],
#        [    46,  23000],
#        [    47,  20000],
#        [    49,  28000],
#        [    47,  30000],
#        [    29,  43000],
#        [    31,  18000],
#        [    31,  74000],
#        [    27, 137000],
#        [    21,  16000],
#        [    28,  44000],
#        [    27,  90000],
#        [    35,  27000],
#        [    33,  28000],
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier()

clf = clf.fit(x_train, y_train)

# %%
y_pred = predict(x_test)
y_pred

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_pred, y_test)

# %%
from sklearn.metrics import classification_report

classes = ['0', '1']

classification_report(y_test, y_pred, target_names=classes)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# %%
import matplotlib.pyplot as plt
import pandas as pd


df1 = df.head(25)
df1.plot(kin='bar', figize=(20,10))
plt.grid(which='major' linestyle='-', linewidth='1', color='green')
plt.grid(which='minor' linestyle=':', linewidth='1', color='black')
plt.show()
